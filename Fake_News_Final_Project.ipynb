# %%
# ===========================================
# Cell 1 – Setup & Library Installation
# ===========================================

# If these are already installed in your environment, you can comment them out
# !pip install nltk lime --quiet

print("Extra libraries installed (nltk, lime). Now import everything in the next cell.")
# Out:
#   DEPRECATION: Building 'lime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'lime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Extra libraries installed (nltk, lime). Now import everything in the next cell.

# %%
# ===========================================
# Cell 2 – Imports
# ===========================================

import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    precision_score, recall_score, f1_score, roc_auc_score,
    accuracy_score, classification_report, confusion_matrix,
    roc_curve, auc
)
from sklearn.model_selection import RandomizedSearchCV

# NLTK
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# LIME
from lime.lime_text import LimeTextExplainer

# TensorFlow / Keras (for LSTM & CNN later)
try:
    import tensorflow as tf
except ImportError:
    # !pip install tensorflow --quiet
    import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Embedding, LSTM, Conv1D, MaxPooling1D,
    Flatten, Dropout, Dense
)

# Force CPU so it runs on any machine (Windows / Intel / M-series)
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# NLTK downloads (run once)
nltk.download('stopwords')
nltk.download('wordnet')

# Plot style
sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 110

print("All libraries imported successfully!")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ompandya/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ompandya/nltk_data...
# All libraries imported successfully!

# %%
# ===========================================
# Cell 3 – Load and Combine Datasets
# ===========================================

fake_df = pd.read_csv("Fake.csv")
true_df = pd.read_csv("True.csv")

# Labels: 1 = Fake, 0 = Real (same as before)
fake_df["label"] = 1
true_df["label"] = 0

df = pd.concat([fake_df, true_df], ignore_index=True)

print("Combined dataset size:", df.shape)
print("\nLabel counts (0 = Real, 1 = Fake):")
print(df["label"].value_counts())
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 # ===========================================
#       2 # Cell 3 – Load and Combine Datasets
#       3 # ===========================================
# ----> 5 fake_df = pd.read_csv("data/Fake.csv")
#       6 true_df = pd.read_csv("data/True.csv")
#       8 # Labels: 1 = Fake, 0 = Real (same as before)
#
# ...
